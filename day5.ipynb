# %%
import seaborn
import pandas
#libraries with additional function

# %%
# comma seperated value csv
#read_csv function is use to convert comma seperated value(csv) into table form
data=pandas.read_csv('/content/penguins.csv')# read_csv is panadas function to laod and manupilate dataset
data
#bill_length_mm=length of a penguin's bill (beak) in millimeters. This measurement is an important feature for distinguishing between different penguin species and understanding their physical characteristics.
#bill_depth_mm=depth of a penguin's bill (beak)
#flipper_length_mm=length of flipper(a flat arm that is part of the body of some sea animals which they use for swimming)
#body_mass=body weight
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
data['species'].value_counts()#data about three species and adelie appearnce of Adelie in table is maximum,then Gentoo and last one Chinstrap
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
data['island'].value_counts()#The data is about three island named 'Biscoe',''Dream','Torgeren'
#Biscoe is appear more that is 168 times, Dream appear less than Biscoe that 124 times Torgersen appear least that is 52 times
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
data['sex'].value_counts()#here the number of male penguin are more that the number of female penguin
#male appear 168 times and female appear 165 times
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
 pandas.pivot_table(data,index='species',columns='sex',values='body_mass_g',aggfunc='mean')
# Out:
# sex             FEMALE         MALE
# species
# Adelie     3368.835616  4043.493151
# Chinstrap  3527.205882  3938.970588
# Gentoo     4679.741379  5484.836066

# %%
data.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# ...

# %%
data['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
data.iloc[:,2:4]
# Out:
#      bill_length_mm  bill_depth_mm
# 0              39.1           18.7
# 1              39.5           17.4
# 2              40.3           18.0
# 3               NaN            NaN
# 4              36.7           19.3
# ..              ...            ...
# 339             NaN            NaN
# 340            46.8           14.3
# 341            50.4           15.7
# 342            45.2           14.8
# 343            49.9           16.1
#
# [344 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['bill_length_mm'].plot(kind='hist', bins=20, title='bill_length_mm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['bill_depth_mm'].plot(kind='hist', bins=20, title='bill_depth_mm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.iloc[:,2:6]
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 3               NaN            NaN                NaN          NaN
# 4              36.7           19.3              193.0       3450.0
# ..              ...            ...                ...          ...
# 339             NaN            NaN                NaN          NaN
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [344 rows x 4 columns]

# %%
seaborn.relplot(data=data,kind='line',x='body_mass_g',y='flipper_length_mm') #as bodymass increses flipper length increases

# %%
seaborn.relplot(data=data,kind='line',x='body_mass_g',y='bill_depth_mm')

# %%
seaborn.relplot(data=data,kind='line',x='body_mass_g',y='bill_depth_mm')

# %%
seaborn.relplot(data=data,kind='line',x='flipper_length_mm',y='bill_length_mm')as fliper lenght increses bill lenght may increses

# %%
seaborn.relplot(data=data,kind='line',x='flipper_length_mm',y='bill_depth_mm')

# %%
#distribution of data called Histogram
seaborn.displot(data,x='flipper_length_mm')#seaborn.displot, a function for creating distribution plots in the Seaborn library.
#when you only specify the x parameter, the default y-axis represents the frequency (or count) of the values in the x-axis variable.
#x-numeric data column
#y-count
#vertical bar can change
#penguin having flipper_length_mm is between 190 to 195 is appear more than other
#more penguin has  flipper_length_mm is between 190 to 195

# %%
seaborn.displot(data,x='bill_length_mm')#penguins having bill lenght between 45 to 48 presen maore in table

# %%
seaborn.displot(data,x='flipper_length_mm',bins=2)#The bins parameter in seaborn.displot specifies the number of bins to use in the histogram or the bin edges.
# By default, Seaborn automatically determines the number of bins,
#but you can customize it for more control over the plot's granularity.

# %%
seaborn.displot(data,x='flipper_length_mm',binwidth=10) #binwidth parameter in seaborn.displot allows you to specify the width of each bin,

# %%
seaborn.displot(data,x='bill_length_mm_')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-957abaa87c04> in <cell line: 1>()
# ----> 1 seaborn.displot(data,x='bill_length_mm_')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2106 ):
#    2107
# -> 2108     p = _DistributionPlotter(
#    2109         data=data,
#    2110         variables=dict(x=x, y=y, hue=hue, weights=weights, row=row, col=col),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in __init__(self, data, variables)
#     108     ):
#     109
# --> 110         super().__init__(data=data, variables=variables)
#     111
#     112     @property
#
# ...

# %%
tips=seaborn.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
seaborn.displot(tips,x='size')

# %%
seaborn.displot(tips,x='day')

# %%
seaborn.displot(tips,x='total_bill',hue='smoker')

# %%
seaborn.displot(tips,x='total_bill',hue='smoker',multiple='dodge')

# %%
seaborn.displot(tips,x='total_bill',col='smoker') #plot histogram side by side

# %%
seaborn.catplot(data,x='species',y='total_bill')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-705b6ea65523> in <cell line: 1>()
# ----> 1 seaborn.catplot(data,x='species',y='total_bill')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2779             raise ValueError("Cannot pass values for both `x` and `y`.")
#    2780
# -> 2781     p = Plotter(
#    2782         data=data,
#    2783         variables=dict(
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
# ...

# %%
seaborn.displot(tips,x='total_bill',kind='kde')#kde-kernel density estimation

# %%
seaborn.displot(tips,x='total_bill',kind='kde',hue='smoker')

# %%
#cumulative distribution function
#20-20%
#0-10 -10%
seaborn.displot(tips,x='total_bill',kind='ecdf')

# %%
seaborn.displot(tips,x='total_bill',kind='ecdf',hue='smoker')
#upto 80% of non smoker has bill 30
#upto 50% of smoker has bill 20

# %%
seaborn.displot(tips,x='total_bill',kind='ecdf',hue='sex')

# %%
#categorical data
seaborn.catplot(data=tips,x='day',y='total_bill')
#X=seaborn.categorical
#y =numeric

# %%
seaborn.catplot(data=tips,x='day',y='total_bill',kind='box')
#box
#whiskers=1.5*Third quartile(max),
#whiskers=1.5*first quartile(min) outliers(abnormally high)
#box=
#min
#25 percentile
#50 percentile(medium)
#75 percentile
#maximum

# %%
#IQR=third quartile(75 prcentile) - first quartile(25 percentile)
#IQR_Thur=20-12.5=7.5

#outliers_above_normal=Third quartile+1.5*(IQR_Thur)
#outliers_below_normal=first quartile-1.5*(IQR_Thur)
#remove all outliers

# %%
seaborn.catplot(data=tips,x='day',y='total_bill',hue='time')

# %%
data
#categorical are species,island and sex
#numeric bill_length,bill_depth, flipper_length
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
seaborn.catplot(data=data,x='island',y='bill_depth_mm')

# %%
titanic=seaborn.load_dataset('titanic')
seaborn.load_dataset('titanic')
titanic
#https://jkarakas.github.io/Exploratory-Analysis-of-the-Titanic-Dataset/Titanic_Dataset_Exploratory_Analysis._With_Code.html
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data.shape
# Out:
# (891, 15)

# %%
#The Embarked column in the Titanic dataset is a categorical feature representing the port where the passenger boarded the Titanic.
#C: Cherbourg
#Q: Queenstown
#S: Southampton
#data=pandas.read_csv('/content/titanic.csv')
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
data['age'].value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
data['adult_male'].value_counts()
# Out:
# adult_male
# True     537
# False    354
# Name: count, dtype: int64

# %%
data['alive'].value_counts()
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
data['alone'].value_counts()
# Out:
# alone
# True     537
# False    354
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
pandas.pivot_table(data, index='sex', columns='class', values='age', aggfunc='mean')
# Out:
# class       First     Second      Third
# sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
seaborn.catplot(data=titanic,x='who',y='survived',kind='bar')
#x- catogerical col
#y-numeric col
#average of y for each category of x
#blacklines shoe confidence interval
#A-0
#B-1
#C-0
#avg=1/3 here out of A,B,C only one means B is survived so 1/3

# %%
seaborn.catplot(data=titanic,x='sex',y='survived',kind='bar')

# %%
seaborn.catplot(data=titanic,x='sex',y='age',kind='bar')

# %%
seaborn.catplot(data=titanic,x='class',y='survived',kind='bar')

# %%
seaborn.displot(data,x='pclass')

# %%
seaborn.catplot(data=titanic,kind='bar',x='sex',y='survived',hue='class')

# %%
seaborn.catplot(data=titanic,kind='bar',x='deck',y='survived')
#confidence interval we have confidence that this amount of deck will survive

# %%
seaborn.catplot(data=titanic,kind='bar',x='deck',y='survived',errorbar=None)

# %%
seaborn.catplot(data=titanic,kind='bar',x='deck',y='survived',errorbar=None,hue='class')

# %%
#point plot shows proability of survival of male and female and interaction between two c
#x=cat col
#y-numeric
seaborn.catplot(kind='point',x='sex',y='survived',data=titanic,hue='class',errorbar=None )

# %%
seaborn.catplot(kind='point',x='embark_town',y='survived',data=titanic,hue='class',errorbar=None )
